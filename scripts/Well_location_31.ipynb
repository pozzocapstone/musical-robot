# %%
import numpy as np
import sys
import matplotlib.pyplot as plt
from skimage import io
import pandas as pd
from scipy.signal import find_peaks
from skimage.exposure import equalize_adapthist

# %%
sys.path.insert(0, '/Users/shrilakshmisbonageri/Desktop/UW/DIRECT/capstone/musical-robot/musicalrobot')

# %%
frames = io.imread('../musicalrobot/data/CHCl_CA_DES_5_31_19.tiff')

# %%
plt.imshow(frames[1])
cbar = plt.colorbar()
cbar.ax.set_ylabel('Temperature(cK)')
# Out:
# Text(0, 0.5, 'Temperature(cK)')

# %% [markdown]
# ### Adding all the images in the frame to get a better contrast and reduce noise

# %%
for II in range(frames.shape[0]):
    frame = frames[II]
    img_eq = (frame - np.amin(frame))/(np.amax(frame)-np.amin(frame))
    if II == 0:
        img_ave = img_eq
    else:
        img_ave = img_ave + img_eq
img_average = img_ave/frames.shape[0]
img_eq = (img_ave - np.amin(img_ave))/(np.amax(img_ave)-np.amin(img_ave))

# %%
plt.imshow(img_eq)

# %%
rows = img_eq.shape[0]
columns = img_eq.shape[1]

# %%
column_sum = []
for i in range(0,columns):
    column_sum.append(sum(img_eq[:,i]))
row_sum = []
for j in range(0,rows):
    row_sum.append(sum(img_eq[j,:]))

# %%
column_sum = [x * -1 for x in column_sum]
row_sum = [x * -1 for x in row_sum]

# %%
plt.plot(range(len(column_sum)),column_sum)
plt.xlabel('X-coordinate value')
plt.ylabel('Sum of pixel values over columns')
# Out:
# Text(0, 0.5, 'Sum of pixel values over columns')

# %%
plt.plot(range(len(row_sum)),row_sum)
plt.xlabel('Y-coordinate value')
plt.ylabel('Sum of pixel values over rows')
# Out:
# Text(0, 0.5, 'Sum of pixel values over rows')

# %%
column_troughs = find_peaks(column_sum,distance=10)
column_troughs = column_troughs[0]
row_troughs = find_peaks(row_sum,distance=10)
row_troughs = row_troughs[0]

# %%
X = []
Y = []
i = 0
j = 0
for i in range(0,8):
    for j in range(0,12):
        X.append(column_troughs[j])
        j = j + 1
        Y.append(row_troughs[i])
    i = i + 1

# %%
well_location = pd.DataFrame(list(zip(X, Y)),columns =['X', 'Y'])

# %%
# To easily access the X and Y coordinates
x = well_location['X']
y = well_location['Y']
well_location
# Out:
#       X    Y
# 0     9   17
# 1    21   17
# 2    32   17
# 3    45   17
# 4    59   17
# 5    73   17
# 6    87   17
# 7   100   17
# 8   114   17
# 9   127   17
# 10  139   17
# 11  151   17
# 12    9   31
# 13   21   31
# 14   32   31
# 15   45   31
# 16   59   31
# 17   73   31
# 18   87   31
# 19  100   31
# 20  114   31
# 21  127   31
# 22  139   31
# 23  151   31
# 24    9   43
# 25   21   43
# 26   32   43
# 27   45   43
# 28   59   43
# 29   73   43
# ..  ...  ...
# 66   87   84
# 67  100   84
# 68  114   84
# 69  127   84
# 70  139   84
# 71  151   84
# 72    9   97
# 73   21   97
# 74   32   97
# 75   45   97
# 76   59   97
# 77   73   97
# 78   87   97
# 79  100   97
# 80  114   97
# 81  127   97
# 82  139   97
# 83  151   97
# 84    9  109
# 85   21  109
# 86   32  109
# 87   45  109
# 88   59  109
# 89   73  109
# 90   87  109
# 91  100  109
# 92  114  109
# 93  127  109
# 94  139  109
# 95  151  109
#
# [96 rows x 2 columns]

# %%
plt.imshow(img_eq)
plt.scatter(x,y)
plate_x = x[4] + 7
plate_y = y[48]
plt.scatter(plate_x,plate_y)
# The above coordinates can be used to measure the temperature of the well plate assuming that
#he temperature is uniform all over the well plate.

# %% [markdown]
# ### Finding pixel intensity in all the wells in each frame

# %%
import irtemp

# %%
irtemp.centikelvin_to_celsius(30000)
# Out:
# 26.85

# %%
# List to store lists of temperature at all the well in each frame.
temp = []
for i in range(96):
    # List to store temperature at a well in each frame.
    comp_temp = []
    for frame in frames:
        comp_temp.append(irtemp.centikelvin_to_celsius(frame[y[i]][x[i]]))
    temp.append(comp_temp)

# %%
plate_temp = []
for frame in frames:
    plate_temp.append(irtemp.centikelvin_to_celsius(frame[plate_y,plate_x]))

# %%
len(plate_temp)
# Out:
# 6668

# %%
# Temperature at each of 96 well plates can be accessed
# using the well plate number as the list index
len(temp)
# The length of the list gives the number of wells at which
# temperature is observed over a period of time.
# Out:
# 96

# %%
# Each list in the list 'temp' gives the temperature
# at the required well in each frame
len(temp[1])
# Out:
# 6668

# %% [markdown]
# ### Temperature of the wellplate

# %% [markdown]
# ### Plotting

# %%
font = {
        'weight': 'normal',
        'size': 12,
        }
plt.plot(plate_temp,temp[12])
plt.ylabel('Temperature of the sample($^\circ$C)',fontdict=font)
plt.xlabel('Temperature of the well plate($^\circ$C)',fontdict=font)
# Out:
# Text(0.5, 0, 'Temperature of the well plate($^\\circ$C)')
